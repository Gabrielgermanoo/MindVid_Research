# %%
import yt_dlp as youtube_dl
import pandas as pd

# %%
hashtags_list = {
    # "ansiedade": ["#ansiedade", "#transtornodeansiedade"],
    # "depressao": ["#depressao", "#transtornodepressivo"],
    # "TDAH": ["#TDAH", "#transtornodedeficitdeatencaohiperatividade"],
    "TEA": ["#autismo", "#transtornodoespectroautista"],
}

# %%
# download method
def download_video(save_directory, link, urls, csv_path, key, cont):
    ydl_opts = {
                'format': 'bestaudio/best',
                    'postprocessors': [{
                        'key': 'FFmpegExtractAudio',
                        'preferredcodec': 'wav',
                        'preferredquality': '192',
                    }],
                    'outtmpl': save_directory + '/' + str(cont) + '_%(id)s.%(ext)s',
                    }
    try:
        with youtube_dl.YoutubeDL(ydl_opts) as ydl:
            ydl.download([link])
        cont += 1
    except youtube_dl.utils.DownloadError:
        urls = urls.drop(cont)
        urls = urls.reset_index(drop=True)
        urls.to_csv(csv_path + '/' + key + '.csv', index=False, header=False)

# %%
df = pd.read_csv(f'./CSV/TEA/TEA2.csv')
save_directory = './Videos/TEA'
cont = 101
for link in df['Link']:
    download_video(save_directory, link, df, './CSV/TEA', 'TEA', cont)
    print('Downloaded')
    cont += 1
# Out:
# [Instagram] Extracting URL: https://www.instagram.com/reel/C6s8VIiuQTf/?igsh=M3g1b2JrajJqY3Nl
# [Instagram] C6s8VIiuQTf: Setting up session
# [Instagram] C6s8VIiuQTf: Downloading JSON metadata
# [info] C6s8VIiuQTf: Downloading 1 format(s): dash-409298158564913ad
# [download] Destination: Videos\TEA\101_C6s8VIiuQTf.m4a
# [download] 100% of  365.77KiB in 00:00:00 at 3.46MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\101_C6s8VIiuQTf.m4a"
# [ExtractAudio] Destination: Videos\TEA\101_C6s8VIiuQTf.wav
# Deleting original file Videos\TEA\101_C6s8VIiuQTf.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C6BeEKrgNXQ/?igsh=MW9ycmMwZHhjbjV4cA==
# [Instagram] C6BeEKrgNXQ: Setting up session
# [Instagram] C6BeEKrgNXQ: Downloading JSON metadata
# [info] C6BeEKrgNXQ: Downloading 1 format(s): dash-796037435778876ad
# [download] Destination: Videos\TEA\102_C6BeEKrgNXQ.m4a
# [download] 100% of   36.10KiB in 00:00:00 at 899.01KiB/s
# [FixupM4a] Correcting container of "Videos\TEA\102_C6BeEKrgNXQ.m4a"
# [ExtractAudio] Destination: Videos\TEA\102_C6BeEKrgNXQ.wav
# Deleting original file Videos\TEA\102_C6BeEKrgNXQ.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C6ojvTFxCLE/?igsh=aXJ4dXVtMDRpcGJz
# [Instagram] C6ojvTFxCLE: Setting up session
# [Instagram] C6ojvTFxCLE: Downloading JSON metadata
# [info] C6ojvTFxCLE: Downloading 1 format(s): dash-1436294310593640ad
# [download] Destination: Videos\TEA\103_C6ojvTFxCLE.m4a
# [download] 100% of  163.06KiB in 00:00:00 at 968.15KiB/s
# [FixupM4a] Correcting container of "Videos\TEA\103_C6ojvTFxCLE.m4a"
# [ExtractAudio] Destination: Videos\TEA\103_C6ojvTFxCLE.wav
# Deleting original file Videos\TEA\103_C6ojvTFxCLE.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C6jOzhvuAbo/?igsh=NWhwMWp5OG1wcjV2
# [Instagram] C6jOzhvuAbo: Setting up session
# [Instagram] C6jOzhvuAbo: Downloading JSON metadata
# [info] C6jOzhvuAbo: Downloading 1 format(s): dash-819063456739400ad
# [download] Destination: Videos\TEA\104_C6jOzhvuAbo.m4a
# [download] 100% of   64.20KiB in 00:00:00 at 1.30MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\104_C6jOzhvuAbo.m4a"
# [ExtractAudio] Destination: Videos\TEA\104_C6jOzhvuAbo.wav
# Deleting original file Videos\TEA\104_C6jOzhvuAbo.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C5MbkMLxLhy/?igsh=aHl4ODhhYWNkenkw
# [Instagram] C5MbkMLxLhy: Setting up session
# [Instagram] C5MbkMLxLhy: Downloading JSON metadata
# [info] C5MbkMLxLhy: Downloading 1 format(s): dash-1105666520657435ad
# [download] Destination: Videos\TEA\105_C5MbkMLxLhy.m4a
# [download] 100% of    1.04MiB in 00:00:00 at 11.45MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\105_C5MbkMLxLhy.m4a"
# [ExtractAudio] Destination: Videos\TEA\105_C5MbkMLxLhy.wav
# Deleting original file Videos\TEA\105_C5MbkMLxLhy.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C4JkSTAOdFl/?igsh=MW1zZWhydG8ycDdkcg==
# [Instagram] C4JkSTAOdFl: Setting up session
# [Instagram] C4JkSTAOdFl: Downloading JSON metadata
# [info] C4JkSTAOdFl: Downloading 1 format(s): dash-1052313459167474ad
# [download] Destination: Videos\TEA\106_C4JkSTAOdFl.m4a
# [download] 100% of  223.61KiB in 00:00:00 at 1.18MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\106_C4JkSTAOdFl.m4a"
# [ExtractAudio] Destination: Videos\TEA\106_C4JkSTAOdFl.wav
# Deleting original file Videos\TEA\106_C4JkSTAOdFl.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C4LeElQrv3F/?igsh=bXY4bXJibGF3cTly
# [Instagram] C4LeElQrv3F: Setting up session
# [Instagram] C4LeElQrv3F: Downloading JSON metadata
# [info] C4LeElQrv3F: Downloading 1 format(s): dash-713383374289508ad
# [download] Destination: Videos\TEA\107_C4LeElQrv3F.m4a
# [download] 100% of  694.08KiB in 00:00:00 at 8.32MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\107_C4LeElQrv3F.m4a"
# [ExtractAudio] Destination: Videos\TEA\107_C4LeElQrv3F.wav
# Deleting original file Videos\TEA\107_C4LeElQrv3F.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C5tuGbgxFZq/?igsh=MWNvYzV0eGQzYWtsZg==
# [Instagram] C5tuGbgxFZq: Setting up session
# [Instagram] C5tuGbgxFZq: Downloading JSON metadata
# [info] C5tuGbgxFZq: Downloading 1 format(s): dash-725105536475770ad
# [download] Destination: Videos\TEA\108_C5tuGbgxFZq.m4a
# [download] 100% of  744.01KiB in 00:00:00 at 8.92MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\108_C5tuGbgxFZq.m4a"
# [ExtractAudio] Destination: Videos\TEA\108_C5tuGbgxFZq.wav
# Deleting original file Videos\TEA\108_C5tuGbgxFZq.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C59CX9UxCSA/?igsh=MXFhYXl2dmVudzE5aQ==
# [Instagram] C59CX9UxCSA: Setting up session
# [Instagram] C59CX9UxCSA: Downloading JSON metadata
# [info] C59CX9UxCSA: Downloading 1 format(s): dash-1485307562365584ad
# [download] Destination: Videos\TEA\109_C59CX9UxCSA.m4a
# [download] 100% of  689.80KiB in 00:00:00 at 3.06MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\109_C59CX9UxCSA.m4a"
# [ExtractAudio] Destination: Videos\TEA\109_C59CX9UxCSA.wav
# Deleting original file Videos\TEA\109_C59CX9UxCSA.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C6kCur-R-dI/?igsh=NWI3cW1mOTNuNXFt
# [Instagram] C6kCur-R-dI: Setting up session
# [Instagram] C6kCur-R-dI: Downloading JSON metadata
# [info] C6kCur-R-dI: Downloading 1 format(s): dash-3687454218239160ad
# [download] Destination: Videos\TEA\110_C6kCur-R-dI.m4a
# [download] 100% of  832.19KiB in 00:00:00 at 11.16MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\110_C6kCur-R-dI.m4a"
# [ExtractAudio] Destination: Videos\TEA\110_C6kCur-R-dI.wav
# Deleting original file Videos\TEA\110_C6kCur-R-dI.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C6jVCL6L2lo/?igsh=b25yZ2Yxc24weTc3
# [Instagram] C6jVCL6L2lo: Setting up session
# [Instagram] C6jVCL6L2lo: Downloading JSON metadata
# [info] C6jVCL6L2lo: Downloading 1 format(s): dash-1778491935888054ad
# [download] Destination: Videos\TEA\111_C6jVCL6L2lo.m4a
# [download] 100% of    1.14MiB in 00:00:00 at 8.86MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\111_C6jVCL6L2lo.m4a"
# [ExtractAudio] Destination: Videos\TEA\111_C6jVCL6L2lo.wav
# Deleting original file Videos\TEA\111_C6jVCL6L2lo.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C5bQwTTOqgJ/?igsh=MTNmZ2tybnNjYnE3NA==
# [Instagram] C5bQwTTOqgJ: Setting up session
# [Instagram] C5bQwTTOqgJ: Downloading JSON metadata
# [info] C5bQwTTOqgJ: Downloading 1 format(s): dash-3808353672819655ad
# [download] Destination: Videos\TEA\112_C5bQwTTOqgJ.m4a
# [download] 100% of  336.05KiB in 00:00:00 at 3.71MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\112_C5bQwTTOqgJ.m4a"
# [ExtractAudio] Destination: Videos\TEA\112_C5bQwTTOqgJ.wav
# Deleting original file Videos\TEA\112_C5bQwTTOqgJ.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C4wEfBtxYGv/?igsh=MTNxN2J3bTZzbnlsNA==
# [Instagram] C4wEfBtxYGv: Setting up session
# [Instagram] C4wEfBtxYGv: Downloading JSON metadata
# [info] C4wEfBtxYGv: Downloading 1 format(s): dash-759647456118788ad
# [download] Destination: Videos\TEA\113_C4wEfBtxYGv.m4a
# [download] 100% of  860.80KiB in 00:00:00 at 8.64MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\113_C4wEfBtxYGv.m4a"
# [ExtractAudio] Destination: Videos\TEA\113_C4wEfBtxYGv.wav
# Deleting original file Videos\TEA\113_C4wEfBtxYGv.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C6uivqZrob8/?igsh=MWJhcGFiZ2pyOXF1Yw==
# [Instagram] C6uivqZrob8: Setting up session
# [Instagram] C6uivqZrob8: Downloading JSON metadata
# [info] C6uivqZrob8: Downloading 1 format(s): dash-453278397067049ad
# [download] Destination: Videos\TEA\114_C6uivqZrob8.m4a
# [download] 100% of  115.02KiB in 00:00:00 at 1.49MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\114_C6uivqZrob8.m4a"
# [ExtractAudio] Destination: Videos\TEA\114_C6uivqZrob8.wav
# Deleting original file Videos\TEA\114_C6uivqZrob8.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C5F7fSGumRW/?igsh=cnM3d2t6MWt1MjFu
# [Instagram] C5F7fSGumRW: Setting up session
# [Instagram] C5F7fSGumRW: Downloading JSON metadata
# [info] C5F7fSGumRW: Downloading 1 format(s): dash-300479759735868ad
# [download] Destination: Videos\TEA\115_C5F7fSGumRW.m4a
# [download] 100% of  580.30KiB in 00:00:00 at 1.47MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\115_C5F7fSGumRW.m4a"
# [ExtractAudio] Destination: Videos\TEA\115_C5F7fSGumRW.wav
# Deleting original file Videos\TEA\115_C5F7fSGumRW.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C5Js9U-O8m5/?igsh=MTlmMWxidWJmejR3eQ==
# [Instagram] C5Js9U-O8m5: Setting up session
# [Instagram] C5Js9U-O8m5: Downloading JSON metadata
# [info] C5Js9U-O8m5: Downloading 1 format(s): dash-1434920794079256ad
# [download] Destination: Videos\TEA\116_C5Js9U-O8m5.m4a
# [download] 100% of  328.69KiB in 00:00:00 at 5.09MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\116_C5Js9U-O8m5.m4a"
# [ExtractAudio] Destination: Videos\TEA\116_C5Js9U-O8m5.wav
# Deleting original file Videos\TEA\116_C5Js9U-O8m5.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C4YqGKHpRBa/?igsh=MWs4OHdvODc1cHZ6cw==
# [Instagram] C4YqGKHpRBa: Setting up session
# [Instagram] C4YqGKHpRBa: Downloading JSON metadata
# [info] C4YqGKHpRBa: Downloading 1 format(s): dash-400111042662122ad
# [download] Destination: Videos\TEA\117_C4YqGKHpRBa.m4a
# [download] 100% of   51.05KiB in 00:00:00 at 1.24MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\117_C4YqGKHpRBa.m4a"
# [ExtractAudio] Destination: Videos\TEA\117_C4YqGKHpRBa.wav
# Deleting original file Videos\TEA\117_C4YqGKHpRBa.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C5pBRiaOx7V/?igsh=MTE0aTl5czNxdzJreg==
# [Instagram] C5pBRiaOx7V: Setting up session
# [Instagram] C5pBRiaOx7V: Downloading JSON metadata
# [info] C5pBRiaOx7V: Downloading 1 format(s): dash-3701427006799905ad
# [download] Destination: Videos\TEA\118_C5pBRiaOx7V.m4a
# [download] 100% of  435.15KiB in 00:00:00 at 1.63MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\118_C5pBRiaOx7V.m4a"
# [ExtractAudio] Destination: Videos\TEA\118_C5pBRiaOx7V.wav
# Deleting original file Videos\TEA\118_C5pBRiaOx7V.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C5Q1JGnuhez/?igsh=c2Nuc251OGY1MHFp
# [Instagram] C5Q1JGnuhez: Setting up session
# [Instagram] C5Q1JGnuhez: Downloading JSON metadata
# [info] C5Q1JGnuhez: Downloading 1 format(s): dash-327260739978822ad
# [download] Destination: Videos\TEA\119_C5Q1JGnuhez.m4a
# [download] 100% of  878.06KiB in 00:00:00 at 2.57MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\119_C5Q1JGnuhez.m4a"
# [ExtractAudio] Destination: Videos\TEA\119_C5Q1JGnuhez.wav
# Deleting original file Videos\TEA\119_C5Q1JGnuhez.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C4JKnHwLG7r/?igsh=NXE3MXRpYXJmZXU1
# [Instagram] C4JKnHwLG7r: Setting up session
# [Instagram] C4JKnHwLG7r: Downloading JSON metadata
# [info] C4JKnHwLG7r: Downloading 1 format(s): dash-2293894430809857ad
# [download] Destination: Videos\TEA\120_C4JKnHwLG7r.m4a
# [download] 100% of  477.12KiB in 00:00:00 at 4.76MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\120_C4JKnHwLG7r.m4a"
# [ExtractAudio] Destination: Videos\TEA\120_C4JKnHwLG7r.wav
# Deleting original file Videos\TEA\120_C4JKnHwLG7r.m4a (pass -k to keep)
# Downloaded
# [Instagram] Extracting URL: https://www.instagram.com/reel/C5EhVwpvR-S/?igsh=MXR0YmF6bXkwdmxmNA==
# [Instagram] C5EhVwpvR-S: Setting up session
# [Instagram] C5EhVwpvR-S: Downloading JSON metadata
# [info] C5EhVwpvR-S: Downloading 1 format(s): dash-793882366104367ad
# [download] Destination: Videos\TEA\121_C5EhVwpvR-S.m4a
# [download] 100% of  436.26KiB in 00:00:00 at 4.34MiB/s
# [FixupM4a] Correcting container of "Videos\TEA\121_C5EhVwpvR-S.m4a"
# [ExtractAudio] Destination: Videos\TEA\121_C5EhVwpvR-S.wav
# Deleting original file Videos\TEA\121_C5EhVwpvR-S.m4a (pass -k to keep)
# Downloaded

# %%
def audioTranscription(file):
    rec = SpeechRecognition(file)
    if rec == "Speech":
        print("Passou!")
        # Initialize recognizer
        r = sr.Recognizer()

        # Load audio file
        with sr.AudioFile(file) as source:
            audio = r.record(source)

        # Transcribe audio file
        try:
            text = r.recognize_google(audio, language='pt-BR')
            print("Transcription: " + text)
        except Exception as e:
            print("Error: " + str(e))
            text = None

        return text
    else:
        return False
